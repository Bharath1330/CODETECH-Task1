# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharath1330/CODETECH-Task1/blob/main/EDA_on_Lung_cancer_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load data set

# %%
data = pd.read_csv("survey lung cancer.csv")

# %% [markdown]
# Data Overview

# %%
print(data.head())
print(data.info())
print(data.describe())
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %% [markdown]
# Handling Missing Values

# %%
print(data.isnull().sum())
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %% [markdown]
# Data Visualization 1. Histogram

# %%
plt.figure(figsize=(12, 8))
data.hist(bins=20, color='skyblue', edgecolor='black')
plt.tight_layout()
plt.show()

# %% [markdown]
# 2.Box Plot

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=data)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 3.Scatter Plot

# %%
plt.figure(figsize=(12, 8))
sns.pairplot(data)
plt.show()

# %% [markdown]
# 4.Pair plot

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# 5.Correlation Matrix

# %%
numeric_data = data.select_dtypes(include=[np.number])
corr_matrix = numeric_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True, cbar=True)
plt.title('Correlation Heatmap of Lung Cancer Dataset Features')
plt.show()
